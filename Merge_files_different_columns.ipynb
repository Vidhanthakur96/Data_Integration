# %%
import csv
from io import StringIO

# %%
inputs = ["Disc.csv", "Track.csv"]

# %%
fieldnames = []
for filename in inputs:
  with open(filename, "r", newline="",encoding="utf-8-sig") as f_in:
    read = csv.reader(f_in)
    headers = next(read)
    for h in headers:
      if h not in fieldnames:
        fieldnames.append(h)

# %%
fieldnames
# Out:
# ['disc_id',
#  'freedbdiscid',
#  'artist_name',
#  'disc_title',
#  'genre_title',
#  'disc_released',
#  'disc_tracks',
#  'disc_seconds',
#  'disc_language',
#  'track_number',
#  'track_title',
#  'tracks_seconds']

# %%
with open("TrackData.csv", "w", newline="",encoding="utf-8-sig") as f_out:   # Comment 2 below
  writer = csv.DictWriter(f_out, fieldnames=fieldnames)
  for filename in inputs:
    with open(filename, "r", newline="",encoding='utf-8-sig') as f_in:
          reader = csv.DictReader(f_in)  # Uses the field names in this file
          for line in reader:
        # Comment 3 below
            writer.writerow(line)

# %%
import pandas as pd

# %%
file = pd.read_csv("TrackData.csv")
# Out:
# C:\Users\vidha\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (3,4,8,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
file.to_csv("TrackData.csv", header=fieldnames, index=False)

# %%
file2 = pd.read_csv("TrackData.csv")

# %%
file2.tail()
# Out:
#          disc_id  freedbdiscid artist_name disc_title genre_title  \
# 1798569   252275           NaN       P.198        NaN         NaN
# 1798570   252275           NaN       P.198        NaN         NaN
# 1798571   252275           NaN       P.198        NaN         NaN
# 1798572   252275           NaN       P.198        NaN         NaN
# 1798573   252275           NaN       P.198        NaN         NaN
#
#          disc_released  disc_tracks  disc_seconds disc_language  track_number  \
# 1798569            NaN          NaN           NaN           NaN           6.0
# 1798570            NaN          NaN           NaN           NaN           7.0
# 1798571            NaN          NaN           NaN           NaN           8.0
# 1798572            NaN          NaN           NaN           NaN           9.0
# 1798573            NaN          NaN           NaN           NaN          10.0
#
#                                track_title  tracks_seconds
# ...

# %%
import numpy as np

# %%
 file2.replace(np.nan, 0)
# Out:
#          disc_id  freedbdiscid                      artist_name  \
# 0              5      720146.0                      Fats Domino
# 1              7      727827.0                      Tenacious D
# 2              8      734738.0                    Frank Sinatra
# 3             11      751378.0                   Brownie Mcghee
# 4             13      753170.0  Sonny Terry And Brownie Mc Ghee
# ...          ...           ...                              ...
# 1798569   252275           0.0                            P.198
# 1798570   252275           0.0                            P.198
# 1798571   252275           0.0                            P.198
# 1798572   252275           0.0                            P.198
# 1798573   252275           0.0                            P.198
#
#                                      disc_title genre_title  disc_released  \
# 0                                   I'M Walking       Blues         1999.0
# ...
